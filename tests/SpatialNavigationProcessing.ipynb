# %% [markdown]
# # Spatial Navigation Processing
#
# This notebook contains the necessary steps to perform the processing on the 4-room spatial navigation task as well as the 2-room spatial navigation task. Due to minor differences in the 2-room task using anonymized items during test, it is recommended that different scripts be used to parse that data (hence the separate example). In principle, study and practice should be parsable in the same way regardless of the number of rooms.

# %% [markdown]
# ## 4-Room Spatial Navigation
#
# First, we'll import the analytics framework.

# %%
import cogrecon.core.data_flexing.spatial_navigation.spatial_navigation_analytics as analytics

# %% [markdown]
# Next, we'll generate the intermediate files from the data set. This is a one-time, computationally expensive process which will save us time in future processing. It can take quite a long time (especially if running over the network as seen below). To selectively generate only parts of the intermediate data set, we can flag elements as False (so they will be ignored).

# %%
analytics.generate_intermediate_files(r'Z:\Kevin\Holodeck\Virtual Navigation Data', full_study_path=False, full_study_look=False, full_test_path=False,
                                full_test_look=False, full_practice_path=False, full_practice_look=False,
                                full_test_2d=False, full_test_vr=True)

# %% [markdown]
# Next, we'll run some of our additional analyses on the intermediate files. This includes calculating:
#  * Item-Specific Efficiency Metrics
#  * Study-Path Efficiency Metrics
#  * Basic Exploration Metrics
#  * Segmentation Analysis

# %%
intermediate_files_dir = r'C:\Users\Kevin\Documents\GitHub\msl-iposition-pipeline\tests\saved_data\2017-06-27_19-13-53'

analytics.generate_segmentation_analysis(intermediate_files_dir + r'\vr_test.csv', '4-room_segmentation_analysis.csv')
# Out:
# INFO (2017-06-28 12:26:56,664): Done parsing command line arguments.
# INFO (2017-06-28 12:26:56,677): Done parsing input files into segments. 188 segments found. Closing input file.
# INFO (2017-06-28 12:26:56,677): Creating output file 4-room_segmentation_analysis.csv.
# INFO (2017-06-28 12:26:56,680): Computing/saving metrics for 188 segments.
# INFO (2017-06-28 12:26:56,805): Closing output file.
# INFO (2017-06-28 12:26:56,809): Done!

# %% [markdown]
# Next, we'll run a conversion on the intermediate files to generate iposition compatible data which can be run through the standard pipeline to analyze item placement.

# %%
import cogrecon.core.data_flexing.spatial_navigation.spatial_navigation_analytics as analytics

intermediate_files_dir = r'C:\Users\Kevin\Documents\GitHub\msl-iposition-pipeline\tests\saved_data\2017-06-27_19-13-53'
analytics.convert_to_iposition(intermediate_files_dir + r'\vr_test.csv', r'C:\Users\Kevin\Documents\GitHub\msl-iposition-pipeline\tests\4-room-iposition')

# %% [markdown]
# Finally, we'll run the pipeline on the files to generate our reconstruction output metrics. Note that for the 4-room deanonymization, doing global deanonymization would involve finding a minimum in 16! possible combinations or 2.09227899e13 combinations. This is extremely impractical to do across nearly 200 trials so we use order to determine minimal placement.

# %%
from cogrecon.core.batch_pipeline import batch_pipeline
import datetime
import logging

batch_pipeline(r"C:\Users\Kevin\Documents\GitHub\msl-iposition-pipeline\tests\saved_data\4-room-iposition",
               datetime.datetime.now().strftime("Holodeck 4-Room Spatial Navigation - %Y-%m-%d_%H-%M-%S.csv"), 
               trial_by_trial_accuracy=False)

batch_pipeline(r"C:\Users\Kevin\Documents\GitHub\msl-iposition-pipeline\tests\saved_data\4-room-iposition",
               datetime.datetime.now().strftime("Holodeck 4-Room Spatial Navigation with Categories - %Y-%m-%d_%H-%M-%S.csv"), 
               category_independence_enabled=True, category_prefixes=True, trial_by_trial_accuracy=False)
# Out:
# INFO:root:Finding files in folder C:\Users\Kevin\Documents\GitHub\msl-iposition-pipeline\tests\saved_data\4-room-iposition.
# INFO:root:Found 47 data files in 0.0090000629425 seconds.
# INFO:root:Parsing files with expected shape None.
# INFO:root:The following ids were found and are being processed: ['001', '003', '004', '005', '006', '008', '009', '010', '011', '012', '013', '014', '016', '017', '018', '020', '021', '022', '025', '101', '102', '103', '104', '105', '106', '108', '109', '110', '112', '113', '114', '115', '116', '123', '124', '125', '127', '128', '129', '131', '134', '135', '145', '146', '147', '148', '149']
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=116.577730726, new_error=128.399161709).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=116.577730726, new_error=126.785944188).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=99.9597965218, new_error=105.1139933).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=80.4215905037, new_error=86.9995647442).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=80.4215905037, new_error=81.6396265831).
# C:\Program Files\Anaconda3\envs\iposition\lib\site-packages\cogrecon\core\batch_pipeline.py:397: RuntimeWarning: Mean of empty slice
#   result.append(agg_functions[iidx]([row[iidx] for row in results]))
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=198.894664647, new_error=261.160775112).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=198.894664647, new_error=208.584822141).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=141.230927409, new_error=226.828671474).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=141.230927409, new_error=164.448206235).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=144.667117486, new_error=175.837708416).
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=170.118856338, new_error=172.664607005).
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=191.200971295, new_error=201.763020743).
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=154.455812337, new_error=178.460085935).
# WARNING:root:['004'] : The transformation function did not reduce the error, removing transform (old_error=154.455812337, new_error=155.80298783).
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=186.628705088, new_error=207.358102853).
# INFO:root:['005'] : The transformation function did not reduce the error, removing rotation and retying (old_error=184.348897582, new_error=201.002773491).
# WARNING:root:['005'] : The transformation function did not reduce the error, removing transform (old_error=184.348897582, new_error=195.757535779).
# INFO:root:['005'] : The transformation function did not reduce the error, removing rotation and retying (old_error=0.0, new_error=9.50350909079e-14).
# WARNING:root:['005'] : The transformation function did not reduce the error, removing transform (old_error=0.0, new_error=1.06581410364e-13).
# INFO:root:['005'] : The transformation function did not reduce the error, removing rotation and retying (old_error=0.0, new_error=9.50350909079e-14).
# WARNING:root:['005'] : The transformation function did not reduce the error, removing transform (old_error=0.0, new_error=1.06581410364e-13).
# INFO:root:['006'] : The transformation function did not reduce the error, removing rotation and retying (old_error=131.498696991, new_error=137.244322619).
# WARNING:root:['006'] : The transformation function did not reduce the error, removing transform (old_error=131.498696991, new_error=131.864780718).
# INFO:root:['006'] : The transformation function did not reduce the error, removing rotation and retying (old_error=126.521351058, new_error=156.03687753).
# WARNING:root:['006'] : The transformation function did not reduce the error, removing transform (old_error=126.521351058, new_error=130.809668318).
# INFO:root:['008'] : The transformation function did not reduce the error, removing rotation and retying (old_error=165.230437452, new_error=172.407550952).
# INFO:root:['008'] : The transformation function did not reduce the error, removing rotation and retying (old_error=117.622637986, new_error=125.180836145).
# INFO:root:['008'] : The transformation function did not reduce the error, removing rotation and retying (old_error=75.8959955476, new_error=85.2852558911).
# WARNING:root:['008'] : The transformation function did not reduce the error, removing transform (old_error=75.8959955476, new_error=75.8998010136).
# INFO:root:['008'] : The transformation function did not reduce the error, removing rotation and retying (old_error=65.7117304914, new_error=124.844394665).
# WARNING:root:['008'] : The transformation function did not reduce the error, removing transform (old_error=65.7117304914, new_error=81.8151794055).
# INFO:root:['009'] : The transformation function did not reduce the error, removing rotation and retying (old_error=82.5326892745, new_error=83.7491027405).
# INFO:root:['009'] : The transformation function did not reduce the error, removing rotation and retying (old_error=125.20457533, new_error=192.898673116).
# WARNING:root:['009'] : The transformation function did not reduce the error, removing transform (old_error=125.20457533, new_error=138.806242523).
# INFO:root:['009'] : The transformation function did not reduce the error, removing rotation and retying (old_error=126.030997656, new_error=199.043563348).
# WARNING:root:['009'] : The transformation function did not reduce the error, removing transform (old_error=126.030997656, new_error=147.147704668).
# INFO:root:['009'] : The transformation function did not reduce the error, removing rotation and retying (old_error=57.3645076338, new_error=75.197233351).
# INFO:root:['010'] : The transformation function did not reduce the error, removing rotation and retying (old_error=140.738547401, new_error=162.216438172).
# WARNING:root:['010'] : The transformation function did not reduce the error, removing transform (old_error=140.738547401, new_error=141.435009974).
# INFO:root:['010'] : The transformation function did not reduce the error, removing rotation and retying (old_error=76.8092144309, new_error=105.230300454).
# WARNING:root:['010'] : The transformation function did not reduce the error, removing transform (old_error=76.8092144309, new_error=82.4754405786).
# INFO:root:['011'] : The transformation function did not reduce the error, removing rotation and retying (old_error=110.011268277, new_error=151.677376742).
# WARNING:root:['011'] : The transformation function did not reduce the error, removing transform (old_error=110.011268277, new_error=121.089681122).
# INFO:root:['011'] : The transformation function did not reduce the error, removing rotation and retying (old_error=97.1212065094, new_error=105.855002528).
# INFO:root:['011'] : The transformation function did not reduce the error, removing rotation and retying (old_error=98.410291124, new_error=125.02900472).
# WARNING:root:['011'] : The transformation function did not reduce the error, removing transform (old_error=98.410291124, new_error=108.561186698).
# INFO:root:['011'] : The transformation function did not reduce the error, removing rotation and retying (old_error=63.9660377205, new_error=92.121412117).
# WARNING:root:['011'] : The transformation function did not reduce the error, removing transform (old_error=63.9660377205, new_error=70.3346497695).
# INFO:root:['012'] : The transformation function did not reduce the error, removing rotation and retying (old_error=150.181860679, new_error=239.755475577).
# WARNING:root:['012'] : The transformation function did not reduce the error, removing transform (old_error=150.181860679, new_error=190.358768269).
# INFO:root:['012'] : The transformation function did not reduce the error, removing rotation and retying (old_error=116.00897283, new_error=140.235256812).
# INFO:root:['012'] : The transformation function did not reduce the error, removing rotation and retying (old_error=123.620787363, new_error=175.674803127).
# WARNING:root:['012'] : The transformation function did not reduce the error, removing transform (old_error=123.620787363, new_error=131.731108483).
# INFO:root:['013'] : The transformation function did not reduce the error, removing rotation and retying (old_error=68.7660394819, new_error=129.296050978).
# WARNING:root:['013'] : The transformation function did not reduce the error, removing transform (old_error=68.7660394819, new_error=76.5965497919).
# INFO:root:['013'] : The transformation function did not reduce the error, removing rotation and retying (old_error=59.9014244381, new_error=104.359658864).
# WARNING:root:['013'] : The transformation function did not reduce the error, removing transform (old_error=59.9014244381, new_error=72.0281269551).
# INFO:root:['013'] : The transformation function did not reduce the error, removing rotation and retying (old_error=51.0105568874, new_error=78.1062307109).
# WARNING:root:['013'] : The transformation function did not reduce the error, removing transform (old_error=51.0105568874, new_error=55.9412660009).
# INFO:root:['013'] : The transformation function did not reduce the error, removing rotation and retying (old_error=50.188576608, new_error=85.0158853325).
# WARNING:root:['013'] : The transformation function did not reduce the error, removing transform (old_error=50.188576608, new_error=55.3301782433).
# INFO:root:['014'] : The transformation function did not reduce the error, removing rotation and retying (old_error=118.89650437, new_error=125.779339434).
# INFO:root:['014'] : The transformation function did not reduce the error, removing rotation and retying (old_error=118.690964896, new_error=239.668009645).
# WARNING:root:['014'] : The transformation function did not reduce the error, removing transform (old_error=118.690964896, new_error=145.787395104).
# INFO:root:['014'] : The transformation function did not reduce the error, removing rotation and retying (old_error=101.034075257, new_error=164.454579451).
# WARNING:root:['014'] : The transformation function did not reduce the error, removing transform (old_error=101.034075257, new_error=110.852117981).
# INFO:root:['016'] : The transformation function did not reduce the error, removing rotation and retying (old_error=160.67346296, new_error=247.310733092).
# WARNING:root:['016'] : The transformation function did not reduce the error, removing transform (old_error=160.67346296, new_error=174.825332032).
# INFO:root:['016'] : The transformation function did not reduce the error, removing rotation and retying (old_error=143.369282032, new_error=174.095713141).
# INFO:root:['016'] : The transformation function did not reduce the error, removing rotation and retying (old_error=178.734611998, new_error=242.005027028).
# WARNING:root:['016'] : The transformation function did not reduce the error, removing transform (old_error=178.734611998, new_error=191.07506316).
# INFO:root:['017'] : The transformation function did not reduce the error, removing rotation and retying (old_error=134.936289196, new_error=152.870078212).
# WARNING:root:['017'] : The transformation function did not reduce the error, removing transform (old_error=134.936289196, new_error=135.248435611).
# INFO:root:['017'] : The transformation function did not reduce the error, removing rotation and retying (old_error=68.8413837505, new_error=72.7395208784).
# INFO:root:['017'] : The transformation function did not reduce the error, removing rotation and retying (old_error=60.3560041077, new_error=63.8526513629).
# INFO:root:['017'] : The transformation function did not reduce the error, removing rotation and retying (old_error=98.5263519279, new_error=147.908589379).
# WARNING:root:['017'] : The transformation function did not reduce the error, removing transform (old_error=98.5263519279, new_error=107.862870057).
# INFO:root:['018'] : The transformation function did not reduce the error, removing rotation and retying (old_error=159.076558831, new_error=172.016296226).
# WARNING:root:['018'] : The transformation function did not reduce the error, removing transform (old_error=159.076558831, new_error=162.218313534).
# INFO:root:['018'] : The transformation function did not reduce the error, removing rotation and retying (old_error=166.035587264, new_error=219.684894653).
# WARNING:root:['018'] : The transformation function did not reduce the error, removing transform (old_error=166.035587264, new_error=178.567944477).
# INFO:root:['018'] : The transformation function did not reduce the error, removing rotation and retying (old_error=139.246714618, new_error=154.474306218).
# WARNING:root:['018'] : The transformation function did not reduce the error, removing transform (old_error=139.246714618, new_error=139.591090974).
# INFO:root:['018'] : The transformation function did not reduce the error, removing rotation and retying (old_error=167.943345566, new_error=215.794734654).
# WARNING:root:['018'] : The transformation function did not reduce the error, removing transform (old_error=167.943345566, new_error=177.92610791).
# INFO:root:['020'] : The transformation function did not reduce the error, removing rotation and retying (old_error=141.76721208, new_error=162.366762032).
# WARNING:root:['020'] : The transformation function did not reduce the error, removing transform (old_error=141.76721208, new_error=142.566500939).
# INFO:root:['020'] : The transformation function did not reduce the error, removing rotation and retying (old_error=92.508179698, new_error=103.904403516).
# INFO:root:['020'] : The transformation function did not reduce the error, removing rotation and retying (old_error=122.080288794, new_error=122.192491471).
# WARNING:root:['020'] : The transformation function did not reduce the error, removing transform (old_error=122.080288794, new_error=122.560120703).
# INFO:root:['020'] : The transformation function did not reduce the error, removing rotation and retying (old_error=89.9426496067, new_error=119.772570909).
# WARNING:root:['020'] : The transformation function did not reduce the error, removing transform (old_error=89.9426496067, new_error=93.7455742709).
# INFO:root:['021'] : The transformation function did not reduce the error, removing rotation and retying (old_error=204.772207029, new_error=209.143433788).
# INFO:root:['021'] : The transformation function did not reduce the error, removing rotation and retying (old_error=127.275923959, new_error=130.386377444).
# INFO:root:['022'] : The transformation function did not reduce the error, removing rotation and retying (old_error=199.322209239, new_error=264.549021312).
# WARNING:root:['022'] : The transformation function did not reduce the error, removing transform (old_error=199.322209239, new_error=207.063503215).
# INFO:root:['022'] : The transformation function did not reduce the error, removing rotation and retying (old_error=133.756769127, new_error=189.099870333).
# WARNING:root:['022'] : The transformation function did not reduce the error, removing transform (old_error=133.756769127, new_error=141.940404624).
# INFO:root:['022'] : The transformation function did not reduce the error, removing rotation and retying (old_error=149.590800992, new_error=161.373363661).
# INFO:root:['025'] : The transformation function did not reduce the error, removing rotation and retying (old_error=110.527272036, new_error=144.252304109).
# WARNING:root:['025'] : The transformation function did not reduce the error, removing transform (old_error=110.527272036, new_error=118.105321208).
# INFO:root:['025'] : The transformation function did not reduce the error, removing rotation and retying (old_error=75.7267080697, new_error=173.448968478).
# WARNING:root:['025'] : The transformation function did not reduce the error, removing transform (old_error=75.7267080697, new_error=103.28111511).
# INFO:root:['025'] : The transformation function did not reduce the error, removing rotation and retying (old_error=102.881752178, new_error=128.885411359).
# INFO:root:['025'] : The transformation function did not reduce the error, removing rotation and retying (old_error=105.021084333, new_error=147.300967862).
# WARNING:root:['025'] : The transformation function did not reduce the error, removing transform (old_error=105.021084333, new_error=113.459353026).
# INFO:root:['101'] : The transformation function did not reduce the error, removing rotation and retying (old_error=141.480417872, new_error=163.746748497).
# INFO:root:['101'] : The transformation function did not reduce the error, removing rotation and retying (old_error=96.4806077587, new_error=144.753196801).
# WARNING:root:['101'] : The transformation function did not reduce the error, removing transform (old_error=96.4806077587, new_error=109.989563432).
# INFO:root:['101'] : The transformation function did not reduce the error, removing rotation and retying (old_error=110.526397199, new_error=255.749189287).
# WARNING:root:['101'] : The transformation function did not reduce the error, removing transform (old_error=110.526397199, new_error=144.040928416).
# INFO:root:['101'] : The transformation function did not reduce the error, removing rotation and retying (old_error=94.2832501571, new_error=146.644080841).
# WARNING:root:['101'] : The transformation function did not reduce the error, removing transform (old_error=94.2832501571, new_error=104.137815828).
# INFO:root:['102'] : The transformation function did not reduce the error, removing rotation and retying (old_error=151.807700566, new_error=188.435734251).
# INFO:root:['102'] : The transformation function did not reduce the error, removing rotation and retying (old_error=146.145284355, new_error=192.514770636).
# WARNING:root:['102'] : The transformation function did not reduce the error, removing transform (old_error=146.145284355, new_error=153.436505107).
# INFO:root:['103'] : The transformation function did not reduce the error, removing rotation and retying (old_error=204.633288105, new_error=241.293156643).
# WARNING:root:['103'] : The transformation function did not reduce the error, removing transform (old_error=204.633288105, new_error=209.371971598).
# INFO:root:['103'] : The transformation function did not reduce the error, removing rotation and retying (old_error=118.646579165, new_error=177.682854231).
# WARNING:root:['103'] : The transformation function did not reduce the error, removing transform (old_error=118.646579165, new_error=128.01906343).
# INFO:root:['104'] : The transformation function did not reduce the error, removing rotation and retying (old_error=232.949446785, new_error=322.767539926).
# WARNING:root:['104'] : The transformation function did not reduce the error, removing transform (old_error=232.949446785, new_error=255.863696852).
# INFO:root:['105'] : The transformation function did not reduce the error, removing rotation and retying (old_error=140.412735452, new_error=209.198408651).
# WARNING:root:['105'] : The transformation function did not reduce the error, removing transform (old_error=140.412735452, new_error=157.668289903).
# INFO:root:['105'] : The transformation function did not reduce the error, removing rotation and retying (old_error=107.765432199, new_error=181.197438277).
# WARNING:root:['105'] : The transformation function did not reduce the error, removing transform (old_error=107.765432199, new_error=120.129527287).
# INFO:root:['106'] : The transformation function did not reduce the error, removing rotation and retying (old_error=74.9860509357, new_error=122.045354157).
# WARNING:root:['106'] : The transformation function did not reduce the error, removing transform (old_error=74.9860509357, new_error=77.9923737348).
# INFO:root:['106'] : The transformation function did not reduce the error, removing rotation and retying (old_error=94.6769761561, new_error=100.135604012).
# INFO:root:['106'] : The transformation function did not reduce the error, removing rotation and retying (old_error=88.7141341847, new_error=153.273472245).
# WARNING:root:['106'] : The transformation function did not reduce the error, removing transform (old_error=88.7141341847, new_error=104.014550489).
# INFO:root:['108'] : The transformation function did not reduce the error, removing rotation and retying (old_error=310.445138753, new_error=667.260432596).
# WARNING:root:['108'] : The transformation function did not reduce the error, removing transform (old_error=310.445138753, new_error=461.542685291).
# INFO:root:['108'] : The transformation function did not reduce the error, removing rotation and retying (old_error=128.36586763, new_error=152.415908545).
# INFO:root:['108'] : The transformation function did not reduce the error, removing rotation and retying (old_error=63.6499062195, new_error=91.3072492604).
# INFO:root:['109'] : The transformation function did not reduce the error, removing rotation and retying (old_error=210.906561668, new_error=223.281157557).
# INFO:root:['109'] : The transformation function did not reduce the error, removing rotation and retying (old_error=99.1350394816, new_error=114.221775108).
# INFO:root:['109'] : The transformation function did not reduce the error, removing rotation and retying (old_error=139.34333767, new_error=152.950748713).
# INFO:root:['110'] : The transformation function did not reduce the error, removing rotation and retying (old_error=321.305657174, new_error=366.961647973).
# WARNING:root:['110'] : The transformation function did not reduce the error, removing transform (old_error=321.305657174, new_error=341.860570416).
# INFO:root:['110'] : The transformation function did not reduce the error, removing rotation and retying (old_error=243.242658432, new_error=438.376749491).
# WARNING:root:['110'] : The transformation function did not reduce the error, removing transform (old_error=243.242658432, new_error=315.789010077).
# INFO:root:['110'] : The transformation function did not reduce the error, removing rotation and retying (old_error=282.06759476, new_error=290.291758797).
# WARNING:root:['110'] : The transformation function did not reduce the error, removing transform (old_error=282.06759476, new_error=283.847706138).
# INFO:root:['112'] : The transformation function did not reduce the error, removing rotation and retying (old_error=122.99870701, new_error=124.654102917).
# INFO:root:['112'] : The transformation function did not reduce the error, removing rotation and retying (old_error=246.358790529, new_error=281.988374053).
# WARNING:root:['112'] : The transformation function did not reduce the error, removing transform (old_error=246.358790529, new_error=249.084718777).
# INFO:root:['112'] : The transformation function did not reduce the error, removing rotation and retying (old_error=105.034425815, new_error=114.798438931).
# INFO:root:['113'] : The transformation function did not reduce the error, removing rotation and retying (old_error=164.509784024, new_error=177.81117708).
# WARNING:root:['113'] : The transformation function did not reduce the error, removing transform (old_error=164.509784024, new_error=168.549784387).
# INFO:root:['113'] : The transformation function did not reduce the error, removing rotation and retying (old_error=228.080173129, new_error=233.172749164).
# INFO:root:['113'] : The transformation function did not reduce the error, removing rotation and retying (old_error=147.496475163, new_error=164.128287492).
# WARNING:root:['113'] : The transformation function did not reduce the error, removing transform (old_error=147.496475163, new_error=148.343285181).
# INFO:root:['114'] : The transformation function did not reduce the error, removing rotation and retying (old_error=162.79017008, new_error=173.579246648).
# INFO:root:['114'] : The transformation function did not reduce the error, removing rotation and retying (old_error=137.078744861, new_error=139.120774558).
# INFO:root:['114'] : The transformation function did not reduce the error, removing rotation and retying (old_error=154.890437266, new_error=158.108218368).
# INFO:root:['115'] : The transformation function did not reduce the error, removing rotation and retying (old_error=68.9935361488, new_error=77.1944938092).
# INFO:root:['115'] : The transformation function did not reduce the error, removing rotation and retying (old_error=128.946527598, new_error=201.141031084).
# WARNING:root:['115'] : The transformation function did not reduce the error, removing transform (old_error=128.946527598, new_error=143.731899042).
# INFO:root:['115'] : The transformation function did not reduce the error, removing rotation and retying (old_error=73.4040317974, new_error=151.511808323).
# WARNING:root:['115'] : The transformation function did not reduce the error, removing transform (old_error=73.4040317974, new_error=90.8534586635).
# INFO:root:['116'] : The transformation function did not reduce the error, removing rotation and retying (old_error=96.0347355361, new_error=133.815758309).
# WARNING:root:['116'] : The transformation function did not reduce the error, removing transform (old_error=96.0347355361, new_error=102.230080675).
# INFO:root:['116'] : The transformation function did not reduce the error, removing rotation and retying (old_error=105.028227623, new_error=115.096364231).
# WARNING:root:['116'] : The transformation function did not reduce the error, removing transform (old_error=105.028227623, new_error=106.86021059).
# INFO:root:['116'] : The transformation function did not reduce the error, removing rotation and retying (old_error=51.5859599803, new_error=86.0076217006).
# WARNING:root:['116'] : The transformation function did not reduce the error, removing transform (old_error=51.5859599803, new_error=58.4119628373).
# INFO:root:['116'] : The transformation function did not reduce the error, removing rotation and retying (old_error=59.8471804056, new_error=139.868812551).
# WARNING:root:['116'] : The transformation function did not reduce the error, removing transform (old_error=59.8471804056, new_error=78.8959577892).
# INFO:root:['123'] : The transformation function did not reduce the error, removing rotation and retying (old_error=190.800908933, new_error=195.738642363).
# INFO:root:['123'] : The transformation function did not reduce the error, removing rotation and retying (old_error=116.199653518, new_error=118.561530398).
# WARNING:root:['123'] : The transformation function did not reduce the error, removing transform (old_error=116.199653518, new_error=117.422389783).
# INFO:root:['124'] : The transformation function did not reduce the error, removing rotation and retying (old_error=183.650839739, new_error=286.358948133).
# WARNING:root:['124'] : The transformation function did not reduce the error, removing transform (old_error=183.650839739, new_error=205.362122996).
# INFO:root:['124'] : The transformation function did not reduce the error, removing rotation and retying (old_error=154.227900894, new_error=160.85707982).
# INFO:root:['124'] : The transformation function did not reduce the error, removing rotation and retying (old_error=136.523630545, new_error=142.636183752).
# INFO:root:['125'] : The transformation function did not reduce the error, removing rotation and retying (old_error=110.83095415, new_error=148.51347702).
# WARNING:root:['125'] : The transformation function did not reduce the error, removing transform (old_error=110.83095415, new_error=117.464426419).
# INFO:root:['125'] : The transformation function did not reduce the error, removing rotation and retying (old_error=144.57356278, new_error=182.568121842).
# WARNING:root:['125'] : The transformation function did not reduce the error, removing transform (old_error=144.57356278, new_error=150.550593632).
# INFO:root:['125'] : The transformation function did not reduce the error, removing rotation and retying (old_error=69.1791949631, new_error=99.4875203453).
# WARNING:root:['125'] : The transformation function did not reduce the error, removing transform (old_error=69.1791949631, new_error=76.3319273093).
# INFO:root:['125'] : The transformation function did not reduce the error, removing rotation and retying (old_error=45.2241468833, new_error=49.724044386).
# WARNING:root:['125'] : The transformation function did not reduce the error, removing transform (old_error=45.2241468833, new_error=45.7769766683).
# INFO:root:['127'] : The transformation function did not reduce the error, removing rotation and retying (old_error=331.107859606, new_error=402.967494495).
# WARNING:root:['127'] : The transformation function did not reduce the error, removing transform (old_error=331.107859606, new_error=393.716923322).
# INFO:root:['127'] : The transformation function did not reduce the error, removing rotation and retying (old_error=318.626172582, new_error=432.720038346).
# WARNING:root:['127'] : The transformation function did not reduce the error, removing transform (old_error=318.626172582, new_error=417.393097483).
# INFO:root:['127'] : The transformation function did not reduce the error, removing rotation and retying (old_error=383.038243959, new_error=1231.36926862).
# WARNING:root:['127'] : The transformation function did not reduce the error, removing transform (old_error=383.038243959, new_error=1226.48280878).
# INFO:root:['127'] : The transformation function did not reduce the error, removing rotation and retying (old_error=138.282028617, new_error=156.717562157).
# WARNING:root:['127'] : The transformation function did not reduce the error, removing transform (old_error=138.282028617, new_error=138.977080433).
# INFO:root:['128'] : The transformation function did not reduce the error, removing rotation and retying (old_error=106.177066557, new_error=117.147457358).
# WARNING:root:['128'] : The transformation function did not reduce the error, removing transform (old_error=106.177066557, new_error=106.387839861).
# INFO:root:['128'] : The transformation function did not reduce the error, removing rotation and retying (old_error=182.227823902, new_error=225.974334987).
# WARNING:root:['128'] : The transformation function did not reduce the error, removing transform (old_error=182.227823902, new_error=194.910102333).
# INFO:root:['128'] : The transformation function did not reduce the error, removing rotation and retying (old_error=54.5457923911, new_error=109.453520289).
# WARNING:root:['128'] : The transformation function did not reduce the error, removing transform (old_error=54.5457923911, new_error=68.0175864797).
# INFO:root:['128'] : The transformation function did not reduce the error, removing rotation and retying (old_error=49.2402444853, new_error=106.406929079).
# WARNING:root:['128'] : The transformation function did not reduce the error, removing transform (old_error=49.2402444853, new_error=63.1633007825).
# INFO:root:['129'] : The transformation function did not reduce the error, removing rotation and retying (old_error=142.176875827, new_error=221.588161056).
# WARNING:root:['129'] : The transformation function did not reduce the error, removing transform (old_error=142.176875827, new_error=163.520212471).
# INFO:root:['129'] : The transformation function did not reduce the error, removing rotation and retying (old_error=174.241620967, new_error=199.381145157).
# WARNING:root:['129'] : The transformation function did not reduce the error, removing transform (old_error=174.241620967, new_error=174.810332031).
# INFO:root:['129'] : The transformation function did not reduce the error, removing rotation and retying (old_error=128.1752076, new_error=226.646020377).
# WARNING:root:['129'] : The transformation function did not reduce the error, removing transform (old_error=128.1752076, new_error=149.233218137).
# INFO:root:['129'] : The transformation function did not reduce the error, removing rotation and retying (old_error=94.7558404798, new_error=113.461250709).
# WARNING:root:['129'] : The transformation function did not reduce the error, removing transform (old_error=94.7558404798, new_error=95.3639707034).
# INFO:root:['131'] : The transformation function did not reduce the error, removing rotation and retying (old_error=164.060225589, new_error=250.023228437).
# WARNING:root:['131'] : The transformation function did not reduce the error, removing transform (old_error=164.060225589, new_error=182.893208181).
# INFO:root:['131'] : The transformation function did not reduce the error, removing rotation and retying (old_error=150.300820493, new_error=216.145935456).
# WARNING:root:['131'] : The transformation function did not reduce the error, removing transform (old_error=150.300820493, new_error=152.121521028).
# INFO:root:['131'] : The transformation function did not reduce the error, removing rotation and retying (old_error=60.470357891, new_error=121.766700869).
# WARNING:root:['131'] : The transformation function did not reduce the error, removing transform (old_error=60.470357891, new_error=74.9443876369).
# INFO:root:['131'] : The transformation function did not reduce the error, removing rotation and retying (old_error=45.228702946, new_error=55.1969896581).
# INFO:root:['134'] : The transformation function did not reduce the error, removing rotation and retying (old_error=265.443836538, new_error=273.82221852).
# WARNING:root:['134'] : The transformation function did not reduce the error, removing transform (old_error=265.443836538, new_error=273.879376384).
# INFO:root:['134'] : The transformation function did not reduce the error, removing rotation and retying (old_error=137.540954836, new_error=160.732810394).
# WARNING:root:['134'] : The transformation function did not reduce the error, removing transform (old_error=137.540954836, new_error=141.855384896).
# INFO:root:['134'] : The transformation function did not reduce the error, removing rotation and retying (old_error=110.195257756, new_error=139.597645401).
# WARNING:root:['134'] : The transformation function did not reduce the error, removing transform (old_error=110.195257756, new_error=117.81178372).
# INFO:root:['135'] : The transformation function did not reduce the error, removing rotation and retying (old_error=212.593475584, new_error=214.648696545).
# WARNING:root:['135'] : The transformation function did not reduce the error, removing transform (old_error=212.593475584, new_error=216.79302254).
# INFO:root:['135'] : The transformation function did not reduce the error, removing rotation and retying (old_error=76.4756776824, new_error=114.754289661).
# WARNING:root:['135'] : The transformation function did not reduce the error, removing transform (old_error=76.4756776824, new_error=81.6411640466).
# INFO:root:['135'] : The transformation function did not reduce the error, removing rotation and retying (old_error=120.365805373, new_error=177.671697389).
# WARNING:root:['135'] : The transformation function did not reduce the error, removing transform (old_error=120.365805373, new_error=126.00328633).
# INFO:root:['145'] : The transformation function did not reduce the error, removing rotation and retying (old_error=143.517221468, new_error=197.204899151).
# WARNING:root:['145'] : The transformation function did not reduce the error, removing transform (old_error=143.517221468, new_error=149.583954019).
# INFO:root:['145'] : The transformation function did not reduce the error, removing rotation and retying (old_error=150.041533084, new_error=162.033322925).
# INFO:root:['145'] : The transformation function did not reduce the error, removing rotation and retying (old_error=167.373889205, new_error=168.684664536).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=142.985515973, new_error=147.188661699).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=142.985515973, new_error=144.245538355).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=158.713644734, new_error=203.44064574).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=158.713644734, new_error=167.701072297).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=130.520553161, new_error=161.508504044).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=130.520553161, new_error=132.989832282).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=131.285313536, new_error=138.616428255).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=131.285313536, new_error=133.235979429).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=89.2508899386, new_error=96.352389857).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=157.241112638, new_error=166.0823058).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=361.169521788, new_error=607.117629982).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=361.169521788, new_error=604.738211175).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=159.265059416, new_error=166.785622117).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=155.203301573, new_error=158.232258531).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=155.203301573, new_error=158.164274181).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=128.557121933, new_error=132.179731725).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=128.557121933, new_error=129.06443307).
# INFO:root:Done processing all files. Data can be found in Holodeck 4-Room Spatial Navigation - 2017-06-28_12-46-30.csv.
# INFO:root:Finding files in folder C:\Users\Kevin\Documents\GitHub\msl-iposition-pipeline\tests\saved_data\4-room-iposition.
# INFO:root:Found 47 data files in 0.0090000629425 seconds.
# INFO:root:Parsing files with expected shape None.
# INFO:root:The following ids were found and are being processed: ['001', '003', '004', '005', '006', '008', '009', '010', '011', '012', '013', '014', '016', '017', '018', '020', '021', '022', '025', '101', '102', '103', '104', '105', '106', '108', '109', '110', '112', '113', '114', '115', '116', '123', '124', '125', '127', '128', '129', '131', '134', '135', '145', '146', '147', '148', '149']
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=124.386275761, new_error=357.504100047).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=124.386275761, new_error=205.2022176).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=45.1688958303, new_error=147.762096979).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=45.1688958303, new_error=71.9799825599).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=26.2264172023, new_error=38.3035535118).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=19.6228972188, new_error=104.888859138).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=19.6228972188, new_error=49.927399308).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=69.4348357804, new_error=168.698404268).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=69.4348357804, new_error=123.857495987).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=65.5876108945, new_error=73.1468509884).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=37.0604646716, new_error=107.734928617).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=37.0604646716, new_error=52.4057447528).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=53.8614528399, new_error=97.0345650115).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=53.8614528399, new_error=63.0441073714).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=28.1123923258, new_error=37.6535380818).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=19.1666130412, new_error=20.9694526531).
# C:\Program Files\Anaconda3\envs\iposition\lib\site-packages\numpy\linalg\linalg.py:1821: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=84.1655723126, new_error=171.137050534).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=84.1655723126, new_error=115.715483253).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=58.8105966058, new_error=67.3723448613).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=58.8105966058, new_error=61.9543477083).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=12.5653434339, new_error=43.7802066696).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=12.5653434339, new_error=21.4162990473).
# INFO:root:['001'] : The transformation function did not reduce the error, removing rotation and retying (old_error=14.202297831, new_error=81.6671767448).
# WARNING:root:['001'] : The transformation function did not reduce the error, removing transform (old_error=14.202297831, new_error=40.2087416955).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=77.6572618158, new_error=235.759585775).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=77.6572618158, new_error=143.170469795).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=66.5073511946, new_error=168.485898533).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=66.5073511946, new_error=94.4169543649).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=47.0826836508, new_error=189.942272785).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=47.0826836508, new_error=148.395949008).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=37.5987798776, new_error=71.1221276055).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=37.5987798776, new_error=42.0381570068).
# WARNING:root:['003'] : Not enough points were found to be accurate enough to create a geometric transform. It will be skipped.
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=18.2040277869, new_error=55.298315979).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=18.2040277869, new_error=25.2039662746).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=22.6626835695, new_error=53.4824536492).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=22.6626835695, new_error=23.5871015683).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=80.2613354907, new_error=80.8767961255).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=24.6426027821, new_error=37.6115148406).
# WARNING:root:['003'] : Not enough points were found to be accurate enough to create a geometric transform. It will be skipped.
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=26.1173148614, new_error=180.251927398).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=26.1173148614, new_error=88.8255245958).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=28.2411376155, new_error=68.8440752101).
# INFO:root:['003'] : The transformation function did not reduce the error, removing rotation and retying (old_error=24.1039600079, new_error=51.1992748986).
# WARNING:root:['003'] : The transformation function did not reduce the error, removing transform (old_error=24.1039600079, new_error=24.3091503416).
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=63.9798907908, new_error=183.886335617).
# WARNING:root:['004'] : The transformation function did not reduce the error, removing transform (old_error=63.9798907908, new_error=95.9858262617).
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=123.352099541, new_error=230.230494444).
# WARNING:root:['004'] : The transformation function did not reduce the error, removing transform (old_error=123.352099541, new_error=169.510689467).
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=77.80073361, new_error=331.748062604).
# WARNING:root:['004'] : The transformation function did not reduce the error, removing transform (old_error=77.80073361, new_error=226.417470709).
# WARNING:root:['004'] : Not enough points were found to be accurate enough to create a geometric transform. It will be skipped.
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=117.835899619, new_error=615.161047731).
# WARNING:root:['004'] : The transformation function did not reduce the error, removing transform (old_error=117.835899619, new_error=502.614298319).
# INFO:root:['004'] : The transformation function did not reduce the error, removing rotation and retying (old_error=64.3755556522, new_error=293.773060402).
# ...
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=39.5133568748, new_error=779.634550111).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=39.5133568748, new_error=528.018044732).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=26.9992256685, new_error=173.153532514).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=26.9992256685, new_error=83.9594149183).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=26.1244132574, new_error=59.4633578731).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=26.1244132574, new_error=35.3089707437).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=25.5314796269, new_error=1036.49347728).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=25.5314796269, new_error=738.795874283).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=98.9714125597, new_error=163.954016611).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=98.9714125597, new_error=118.747281409).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=86.1851463861, new_error=354.400271163).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=86.1851463861, new_error=210.549192667).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=61.1929163412, new_error=363.943627397).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=61.1929163412, new_error=166.918682696).
# WARNING:root:['146'] : Not enough points were found to be accurate enough to create a geometric transform. It will be skipped.
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=77.3780215676, new_error=82.2753869187).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=77.3780215676, new_error=80.2640014815).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=33.682360958, new_error=51.5838140599).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=33.682360958, new_error=34.0590117336).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=142.204580304, new_error=438.648837577).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=142.204580304, new_error=444.082931481).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=95.3983954929, new_error=187.287948415).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=95.3983954929, new_error=151.654064757).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=40.2371440834, new_error=41.6463975455).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=40.2371440834, new_error=41.6234316072).
# INFO:root:['146'] : The transformation function did not reduce the error, removing rotation and retying (old_error=90.5188638559, new_error=110.964548344).
# WARNING:root:['146'] : The transformation function did not reduce the error, removing transform (old_error=90.5188638559, new_error=91.5472185601).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=45.6279434604, new_error=277.825265359).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=45.6279434604, new_error=187.809583259).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=10.7742559857, new_error=47.5967936114).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=10.7742559857, new_error=21.8558683411).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=14.4536640658, new_error=52.0194343798).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=14.4536640658, new_error=23.1343896262).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=13.5498473892, new_error=45.1785596928).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=13.5498473892, new_error=20.092643456).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=37.4798646238, new_error=47.9434695465).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=37.4798646238, new_error=45.7587493248).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=30.2723433975, new_error=53.1850921012).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=30.2723433975, new_error=35.7003077914).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=15.8130202804, new_error=41.1132951582).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=15.8130202804, new_error=18.086449346).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=11.6139840068, new_error=19.6885419086).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=61.1634851865, new_error=90.1570638659).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=61.1634851865, new_error=65.7053872987).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=22.9538126075, new_error=39.214045372).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=19.5188732241, new_error=23.5421504806).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=34.3268276925, new_error=377.256601339).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=34.3268276925, new_error=201.232581848).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=20.7141110277, new_error=40.3396644847).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=20.7141110277, new_error=26.6209162723).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=24.7061253482, new_error=155.381622494).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=24.7061253482, new_error=96.6188957504).
# INFO:root:['147'] : The transformation function did not reduce the error, removing rotation and retying (old_error=9.68186136956, new_error=62.0790747265).
# WARNING:root:['147'] : The transformation function did not reduce the error, removing transform (old_error=9.68186136956, new_error=31.0527543649).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=105.874002949, new_error=165.845514885).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=105.250562659, new_error=245.011017079).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=105.250562659, new_error=150.482276358).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=67.6576454332, new_error=870.441620095).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=67.6576454332, new_error=871.254790212).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=62.2210882376, new_error=2212.12056652).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=62.2210882376, new_error=2197.22333776).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=105.826224144, new_error=864.061108173).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=105.826224144, new_error=701.777621995).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=45.0288495184, new_error=109.456525121).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=45.0288495184, new_error=99.9564525615).
# WARNING:root:['148'] : Not enough points were found to be accurate enough to create a geometric transform. It will be skipped.
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=92.8167538179, new_error=5614.79050288).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=92.8167538179, new_error=5032.98192454).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=84.8734312063, new_error=94.4298849352).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=32.1872536329, new_error=142.462803794).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=32.1872536329, new_error=84.551797621).
# WARNING:root:['148'] : Not enough points were found to be accurate enough to create a geometric transform. It will be skipped.
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=60.4411413749, new_error=327.83764222).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=60.4411413749, new_error=217.198132804).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=96.8220433124, new_error=258.243320987).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=96.8220433124, new_error=221.815704766).
# INFO:root:['148'] : The transformation function did not reduce the error, removing rotation and retying (old_error=67.2415256728, new_error=2242.06690493).
# WARNING:root:['148'] : The transformation function did not reduce the error, removing transform (old_error=67.2415256728, new_error=2226.52770139).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=60.7200466235, new_error=739.584749379).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=60.7200466235, new_error=485.144440448).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=84.4199976147, new_error=341.277979582).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=84.4199976147, new_error=317.380352642).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=32.2967552719, new_error=45.7568093707).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=32.2967552719, new_error=35.9073552873).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=29.9376757733, new_error=159.425361306).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=29.9376757733, new_error=77.3703136982).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=60.0540022382, new_error=204.763631984).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=60.0540022382, new_error=79.3086491746).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=66.62592729, new_error=106.962208202).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=66.62592729, new_error=73.1694515074).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=37.6820670803, new_error=102.053559208).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=37.6820670803, new_error=101.061561742).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=31.9125742945, new_error=189.67216345).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=31.9125742945, new_error=98.4945961185).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=92.371251996, new_error=157.102520668).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=92.371251996, new_error=131.995123242).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=49.0946945485, new_error=80.6016884455).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=46.8098864677, new_error=350.673615815).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=46.8098864677, new_error=213.79072765).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=25.7704869999, new_error=48.2612390634).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=25.7704869999, new_error=27.9587158604).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=36.1297846727, new_error=120.987520338).
# WARNING:root:['149'] : The transformation function did not reduce the error, removing transform (old_error=36.1297846727, new_error=66.9933646458).
# INFO:root:['149'] : The transformation function did not reduce the error, removing rotation and retying (old_error=20.854582951, new_error=21.5049216884).
# INFO:root:Done processing all files. Data can be found in Holodeck 4-Room Spatial Navigation with Categories - 2017-06-28_12-46-35.csv.

# %%
from cogrecon.core.data_structures import ParticipantData, AnalysisConfiguration
from cogrecon.core.full_pipeline import full_pipeline

subid = '135'

root_path = r'C:\Users\Kevin\Documents\GitHub\msl-iposition-pipeline\tests\saved_data\4-room-iposition'
full_pipeline(ParticipantData.load_from_file(root_path + r'\actual_coordinates.txt', 
                                             root_path + r'\{0}position_data_coordinates.txt'.format(subid), 
                                             None), 
              AnalysisConfiguration(trial_by_trial_accuracy=False), 
              visualize=True)

# %% [markdown]
# ## Statistical Analysis
#
# Now, we'll want to combine the outputs from the various analyses and look for associations.

# %% [markdown]
# ## 2-Room Spatial Navigation
#
# Next, we'll repeat the above process on the 2-room spatial navigation task data.
