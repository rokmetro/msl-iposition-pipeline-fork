# %% [markdown]
# # iPosition Monte Carlo Simulation
#
# This notebook contains various monte carlo simulations for iPosition data. In particular, a few primary methods of simulation are used. Naive 2D simulation, histogram data-driven simulation, and dirichlet distribution simulation are used to determine chance levels. The "actual coordinates" are either from real coordinates or from random coordinates.

# %% [markdown]
# First we need to import the pipeline. You'll need to change this directory to wherever it is stored on your machine.

# %%
from cogrecon.core.full_pipeline import full_pipeline, get_header_labels
from cogrecon.core.data_structures import TrialData, ParticipantData, AnalysisConfiguration

# %% [markdown]
# ## Naive 2D Simulation
#
# This section contains the Naive 2D simulations using either truly random values with random target points or truly random values with actual target points.
#
# First, we define some global variables about our simulation.

# %%
sim_iterations = 10000  # For convenience, the number of iterations each simulation configuration should run

# Define the dimensions, number of items, and iterations for each test
test_configs = [
    {'dims': 2, 'items': 2, 'iterations': sim_iterations},
    {'dims': 2, 'items': 3, 'iterations': sim_iterations},
    {'dims': 2, 'items': 4, 'iterations': sim_iterations},
    {'dims': 2, 'items': 5, 'iterations': sim_iterations},
    {'dims': 2, 'items': 6, 'iterations': sim_iterations}
]

remove_columns = [4, 17, 38]  # Some columns of our output may not average or standard-deviation easily, so we remove those

save_filename = 'naive_2d_monte_carlo.p'  # The filename to save the output as we go

# %%
import numpy as np
import numpy.random as rand
import logging
import time
import os
import pickle

# Disable some outputs that we don't need given our circumstances
logger = logging.getLogger()
logger.disabled = True
np.seterr(invalid='ignore')
# Out:
# {'divide': 'warn', 'invalid': 'ignore', 'over': 'warn', 'under': 'ignore'}

# %%
# Helper for getting the appropriate headers for columns we keep
def get_output_labels():
    headers = get_header_labels()
    headers = np.delete(headers, remove_columns)
    return headers

# Helper for printing our variables as we run
def print_read_friendly(o):
    headers = get_output_labels()
    
    row_format ="{0:55}: {1:15}"
    for h, oo in zip(headers, o):
        print(row_format.format(h, oo))

# Helper for converting our outputs to an easy-to-save format
def get_save_data(_test_configs, _output_labels, _mean_outputs, _std_outputs, _times):
    save_data = {
        'test_configs': _test_configs,
        'output_labels': _output_labels,
        'mean_outputs': _mean_outputs,
        'std_outputs': _std_outputs,
        'times': _times
            }
    return save_data
    
# Helper for saving our data
def checkpoint_data(save_filename, data):
    pickle.dump(data, open(save_filename, 'wb'))

# Helper for getting random data
def get_random_data():
    actual = np.array([np.array([rand.random() for _ in range(dims)]) for _ in range(items)])
    data = np.array([np.array([rand.random() for _ in range(dims)]) for _ in range(items)])
    return actual.tolist(), data.tolist()

# %%
# Lists to store our main outputs
mean_outputs = []
std_outputs = []
times = []

# Iterate through our configurations
for config in test_configs:
    # Get config parameters
    dims = config['dims']
    items = config['items']
    iterations = config['iterations']
    
    # List to store each iteration output - for large iterations, this is the list that can balloon up
    outputs = []
    
    # Record start runtime
    start_time = time.time()
    
    # Iterate the number of times requested
    for _ in range(iterations):
        # Generate random data
        actual, data = get_random_data()
        
        # Run the pipeline
        output = full_pipeline(ParticipantData([TrialData(actual, data)]), AnalysisConfiguration(), visualize=False)[0]
        
        # Delete the removal columns and append the output
        output = np.delete(output, remove_columns, axis=0)
        outputs.append(output)
    
    # Save the runtime, mean of outputs, and standard deviation of outputs (converting to float for that to avoid errors)
    duration = time.time() - start_time
    avgs = np.nanmean(outputs, axis=0)
    stds = np.nanstd([[float(x) for x in inner] for inner in outputs], axis=0)
    
    mean_outputs.append(avgs)
    std_outputs.append(stds)
    times.append(duration)
    
    # Checkpoint/save the data to file
    checkpoint_data(save_filename, get_save_data(test_configs, get_output_labels(), mean_outputs, std_outputs, times))

    # Print a report on this configuration for the user
    print('{0} iterations run in {1} seconds ({2} average) on {3}.'.format(sim_iterations, duration, duration/sim_iterations, config))
    print('_'*100)
    print_read_friendly(avgs)
    print('_'*100)
    print('_'*100)
# Out:
# 10000 iterations run in 62.0460000038 seconds (0.00620460000038 average) on {'dims': 2, 'iterations': 10000, 'items': 2}.
# ____________________________________________________________________________________________________
# Original Misplacement                                  :  0.520941375674
# Original Swap                                          :          0.2476
# Original Edge Resizing                                 : 0.0935075822926
# Original Edge Distortion                               :          1.0036
# Pre-Processed Accurate Placements                      :             2.0
# Pre-Processed Inaccurate Placements                    :             0.0
# Pre-Processed Accuracy Threshold                       :  0.715813297217
# Deanonymized Accurate Placements                       :             2.0
# Deanonymized Inaccurate Placements                     :             0.0
# Deanonymized Accuracy Threshold                        :  0.637286905442
# Raw Deanonymized Misplacement                          :  0.441037979887
# Transformation Auto-Exclusion                          :          0.6453
# Number of Points Excluded From Geometric Transform     :             0.0
# Rotation Theta                                         :             nan
# Scaling                                                :             nan
# Translation Magnitude                                  :             nan
# Geometric Distance Threshold                           :  0.637286905442
# Number of Components                                   :          1.5019
# Accurate Placements                                    :          0.9905
# Inaccurate Placements                                  :          0.0133
# True Swaps                                             :          0.4882
# Partial Swaps                                          :          0.0099
# Cycle Swaps                                            :             0.0
# Partial Cycle Swaps                                    :             0.0
# Misassignment                                          :          0.9962
# Accurate Misassignment                                 :           0.982
# Inaccurate Misassignment                               :          0.0142
# Swap Distance Threshold                                :  0.552373786248
# True Swap Data Distance                                :             nan
# True Swap Actual Distance                              :             nan
# Partial Swap Data Distance                             :             nan
# Partial Swap Actual Distance                           :             nan
# Cycle Swap Data Distance                               :             nan
# Cycle Swap Actual Distance                             :             nan
# Partial Cycle Swap Data Distance                       :             nan
# Partial Cycle Swap Actual Distance                     :             nan
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# 10000 iterations run in 73.6660001278 seconds (0.00736660001278 average) on {'dims': 2, 'iterations': 10000, 'items': 3}.
# ____________________________________________________________________________________________________
# Original Misplacement                                  :  0.521119760861
# Original Swap                                          :          0.2551
# Original Edge Resizing                                 :  0.142036407564
# Original Edge Distortion                               :          1.0065
# Pre-Processed Accurate Placements                      :          2.3575
# Pre-Processed Inaccurate Placements                    :          0.6425
# Pre-Processed Accuracy Threshold                       :  0.727638981242
# Deanonymized Accurate Placements                       :          2.3234
# Deanonymized Inaccurate Placements                     :          0.6766
# Deanonymized Accuracy Threshold                        :  0.578663704374
# Raw Deanonymized Misplacement                          :  0.390363774784
# Transformation Auto-Exclusion                          :          0.5746
# Number of Points Excluded From Geometric Transform     :          0.6766
# Rotation Theta                                         :             nan
# Scaling                                                :             nan
# Translation Magnitude                                  :             nan
# Geometric Distance Threshold                           :  0.578663704374
# Number of Components                                   :          1.8259
# Accurate Placements                                    :          0.7433
# Inaccurate Placements                                  :          0.2477
# True Swaps                                             :          0.2498
# Partial Swaps                                          :          0.2459
# Cycle Swaps                                            :          0.0863
# Partial Cycle Swaps                                    :          0.2529
# Misassignment                                          :           2.009
# Accurate Misassignment                                 :          1.5102
# Inaccurate Misassignment                               :          0.4988
# Swap Distance Threshold                                :  0.517809003126
# True Swap Data Distance                                :             nan
# True Swap Actual Distance                              :             nan
# Partial Swap Data Distance                             :             nan
# Partial Swap Actual Distance                           :             nan
# Cycle Swap Data Distance                               :             nan
# Cycle Swap Actual Distance                             :             nan
# Partial Cycle Swap Data Distance                       :             nan
# Partial Cycle Swap Actual Distance                     :             nan
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# 10000 iterations run in 76.0380001068 seconds (0.00760380001068 average) on {'dims': 2, 'iterations': 10000, 'items': 4}.
# ____________________________________________________________________________________________________
# Original Misplacement                                  :  0.524261652786
# Original Swap                                          :  0.253683333333
# Original Edge Resizing                                 :  0.171146183527
# Original Edge Distortion                               :   1.00838333333
# Pre-Processed Accurate Placements                      :          3.1202
# Pre-Processed Inaccurate Placements                    :          0.8798
# Pre-Processed Accuracy Threshold                       :  0.721930931531
# Deanonymized Accurate Placements                       :          3.0759
# Deanonymized Inaccurate Placements                     :          0.9241
# Deanonymized Accuracy Threshold                        :  0.527008377118
# Raw Deanonymized Misplacement                          :  0.357855380875
# Transformation Auto-Exclusion                          :          0.4284
# Number of Points Excluded From Geometric Transform     :          0.9241
# Rotation Theta                                         :             nan
# Scaling                                                :             nan
# Translation Magnitude                                  :             nan
# Geometric Distance Threshold                           :  0.527008377118
# Number of Components                                   :          2.0756
# Accurate Placements                                    :          0.7609
# Inaccurate Placements                                  :          0.2292
# True Swaps                                             :          0.2643
# Partial Swaps                                          :          0.2333
# Cycle Swaps                                            :          0.1144
# Partial Cycle Swaps                                    :          0.4735
# Misassignment                                          :          3.0099
# Accurate Misassignment                                 :          2.3008
# Inaccurate Misassignment                               :          0.7091
# Swap Distance Threshold                                :  0.462047045312
# True Swap Data Distance                                :             nan
# True Swap Actual Distance                              :             nan
# Partial Swap Data Distance                             :             nan
# Partial Swap Actual Distance                           :             nan
# Cycle Swap Data Distance                               :             nan
# Cycle Swap Actual Distance                             :             nan
# Partial Cycle Swap Data Distance                       :             nan
# Partial Cycle Swap Actual Distance                     :             nan
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# 10000 iterations run in 109.062999964 seconds (0.0109062999964 average) on {'dims': 2, 'iterations': 10000, 'items': 5}.
# ____________________________________________________________________________________________________
# Original Misplacement                                  :  0.521140562369
# Original Swap                                          :         0.24792
# Original Edge Resizing                                 :  0.189638157286
# Original Edge Distortion                               :         0.99991
# Pre-Processed Accurate Placements                      :          3.8195
# Pre-Processed Inaccurate Placements                    :          1.1805
# Pre-Processed Accuracy Threshold                       :   0.70663825373
# Deanonymized Accurate Placements                       :          3.8135
# Deanonymized Inaccurate Placements                     :          1.1865
# Deanonymized Accuracy Threshold                        :  0.481945772534
# Raw Deanonymized Misplacement                          :  0.331655473829
# Transformation Auto-Exclusion                          :          0.3708
# Number of Points Excluded From Geometric Transform     :          1.1865
# Rotation Theta                                         :             nan
# Scaling                                                :             nan
# Translation Magnitude                                  :             nan
# Geometric Distance Threshold                           :  0.481945772534
# Number of Components                                   :          2.2661
# Accurate Placements                                    :          0.7542
# Inaccurate Placements                                  :          0.2319
# True Swaps                                             :           0.269
# Partial Swaps                                          :          0.2234
# Cycle Swaps                                            :          0.1583
# Partial Cycle Swaps                                    :          0.6293
# Misassignment                                          :          4.0139
# Accurate Misassignment                                 :          3.0584
# Inaccurate Misassignment                               :          0.9555
# Swap Distance Threshold                                :  0.423355085247
# True Swap Data Distance                                :             nan
# True Swap Actual Distance                              :             nan
# Partial Swap Data Distance                             :             nan
# Partial Swap Actual Distance                           :             nan
# Cycle Swap Data Distance                               :             nan
# Cycle Swap Actual Distance                             :             nan
# Partial Cycle Swap Data Distance                       :             nan
# Partial Cycle Swap Actual Distance                     :             nan
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# 10000 iterations run in 294.599999905 seconds (0.0294599999905 average) on {'dims': 2, 'iterations': 10000, 'items': 6}.
# ____________________________________________________________________________________________________
# Original Misplacement                                  :  0.521326676253
# Original Swap                                          :         0.24834
# Original Edge Resizing                                 :  0.203099986743
# Original Edge Distortion                               :  0.997293333333
# Pre-Processed Accurate Placements                      :          4.4876
# Pre-Processed Inaccurate Placements                    :          1.5124
# Pre-Processed Accuracy Threshold                       :  0.695969729185
# Deanonymized Accurate Placements                       :          4.5424
# Deanonymized Inaccurate Placements                     :          1.4576
# Deanonymized Accuracy Threshold                        :  0.446872721458
# Raw Deanonymized Misplacement                          :  0.312345120043
# Transformation Auto-Exclusion                          :          0.3116
# Number of Points Excluded From Geometric Transform     :          1.4576
# Rotation Theta                                         :             nan
# Scaling                                                :             nan
# Translation Magnitude                                  :             nan
# Geometric Distance Threshold                           :  0.446872721458
# Number of Components                                   :          2.4501
# Accurate Placements                                    :          0.7578
# Inaccurate Placements                                  :            0.24
# True Swaps                                             :            0.27
# Partial Swaps                                          :          0.2333
# Cycle Swaps                                            :          0.1978
# Partial Cycle Swaps                                    :          0.7512
# Misassignment                                          :          5.0022
# Accurate Misassignment                                 :           3.792
# Inaccurate Misassignment                               :          1.2102
# Swap Distance Threshold                                :  0.390203950296
# True Swap Data Distance                                :             nan
# True Swap Actual Distance                              :             nan
# Partial Swap Data Distance                             :             nan
# Partial Swap Actual Distance                           :             nan
# Cycle Swap Data Distance                               :             nan
# Cycle Swap Actual Distance                             :             nan
# Partial Cycle Swap Data Distance                       :             nan
# Partial Cycle Swap Actual Distance                     :             nan
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________

# %% [markdown]
# Load the data to confirm it saved properly.

# %%
load_data = pickle.load(open(save_filename, "rb"))
print(load_data)
